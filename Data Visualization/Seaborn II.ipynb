# %%
# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

# load the built-in tips dataset
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Regression Line With a Confidence Interval
# A regression line with confidence interval can be handy, for example, when we want to plot the dependence of a tip based on the total bill. It can be done by computing the regression line and the confidence interval with some library (sklearn, statsmodels, SciPy) and then plot the result using Matplotlib. But let's see how easily it can be done with Seaborn.

# %%
# a regression line with a confidence inetrval plot
sns.lmplot(x='total_bill', y='tip', data = tips)
plt.show()

# %% [markdown]
# Now if we want to have two regression lines in one chart – one for female tips and one for male tips – we can modify the code above and use the hue parameter.

# %%
sns.lmplot(x='total_bill',y='tip', data = tips, hue = 'sex')
plt.show()

# %% [markdown]
# On the other hand, we could also have one plot for each of the regression lines and write only one line of code.

# %%
sns.lmplot(x='total_bill',y='tip', data = tips, col = 'sex')
plt.show()

# %% [markdown]
# # Residual Plot
# Another plot that is related to the regression line is a residual plot. We don't need to compute residuals manually and then plot the results. Instead, we can use a built-in function:

# %%
sns.residplot(x='total_bill',y='tip', data = tips)
plt.show()

# %% [markdown]
# There are many more useful functions in the Seaborn library. Let's learn a few more by examples with the tips data-frame.
#
# # Strip Plot

# %%
sns.stripplot(x='day',y ='tip',data = tips, size =5, jitter = True)

# overwrite the original y-label from 'tip' to 'tip ($)'
plt.ylabel('tip ($)')
plt.show()

# %% [markdown]
# # Swarm Plot

# %%
sns.swarmplot(x='day',y='tip',data = tips, hue = 'sex')

# overwrite the original y-label from 'tip' to 'tip ($)'
plt.ylabel('tip ($)')
plt.show()
# Out:
# /home/robyn/anaconda3/envs/LHL_Bootcamp/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/robyn/anaconda3/envs/LHL_Bootcamp/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Boxplot + Violin Plot

# %%
# create a grid with 1 row 2 columns
plt.subplot(1,2,1)

# the first plot
sns.boxplot(x='day',y='tip', data = tips)
plt.ylabel('tip ($)')

plt.subplot(1,2,2)

# the second plot
sns.violinplot(x='day',y='tip', data = tips)
plt.ylabel('tip ($)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Joint Plot
#
# * with histograms:

# %%
sns.jointplot(x='total_bill', y='tip', data = tips)
plt.show()

# %% [markdown]
# * with density estimates:

# %%
sns.jointplot(x='total_bill', y='tip', data = tips, kind = 'kde')
plt.show()

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(tips)
plt.show()

# %% [markdown]
# A pair plot with the hue parameter.

# %%
sns.pairplot(tips, hue = 'sex')
plt.show()

# %% [markdown]
# # Heatmap

# %%
# compute correlations between features
df_corr = tips.corr()

# plot the correlations
sns.heatmap(df_corr)
plt.title('Correlation plot')
plt.show()
