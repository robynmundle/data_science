# %%
# import pandas
import pandas as pd

# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv',sep=',')
df.drop('#',axis=1,inplace=True)

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # Objective: Plot regression line between attack and defense

# %%
# a regression line with a confidence interval plot
sns.lmplot(x='Attack', y='Defense', data = df)
plt.show()

# %% [markdown]
# # Objective: Plot regression line between attack and defense with respect to generation

# %%
# a regression line with a confidence interval plot
sns.lmplot(x='Attack', y='Defense', data = df, hue = 'Generation')
plt.show()

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # Objective: Make boxplot for each feature of dataframe (without Generation and Legendary features) in one plot

# %%
sns.set_style("darkgrid")
df[['Total','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']].boxplot(figsize=(10,8))

# How Lawrence did this:
#new_df = pd.melt(
#    df,
#    id_vars=['Name'],
#    value_vars=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'],
#    var_name = "x",
#    value_name = "y"
#)
#sns.boxplot(x='x', y='y', data=new_df)
#plt.show()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Objective: Plot correlation heatmap of pokemon dataframe (not include features Generation and Legendary)

# %%
# compute correlations between features
df_corr = df[['Total','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']].corr()

# plot the correlations
sns.heatmap(df_corr)
plt.title('Correlation plot')
plt.show()
