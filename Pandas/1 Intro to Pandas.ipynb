# %% [markdown]
# ## Data Wrangling with Python: Intro to Pandas
# Note: Notebook adapted from [here](https://github.com/EricElmoznino/lighthouse_pandas_tutorial/blob/master/pandas_tutorial.ipynb) & [here](https://github.com/sedv8808/LighthouseLabs/tree/main/W02D2) & from LHL's [21 Day Data Challenge](https://data-challenge.lighthouselabs.ca/start)
# #### Instructor: Andrew Berry
# #### Date: March 4, 2021
#
# **Agenda:**
#  - Why Pandas? --- because it's da-BESSSST
#  - Pandas Basics
#      - Pandas Series vs. Pandas DataFrames
#      - .loc() vs. iloc()
#  - Pandas Advance
#      - Filtering
#      - Group bys
#  - Pandas Exercises
#      - Challenge 1
#      - Challenge 2
#
# ### Pandas: Why Pandas? What is it?

# %% [markdown]
# To do data anlaysis with Python, Pandas is a great tool to for dealing with data in a tabular and time series formats. Designed by Wes McKinney as an attempt to port R's dataframes to python.
#
# - Python Package for working with **tables**
# - Similar to SQL & Excel
#     - Faster
#     - More features to manipulate, transform, and aggregate data
# - Easy to handle messy and missing data
# - Great at working with large data files
# - When combing with other Python libraries, it's fairly easy to create bautiful and customazied visuals. Easy integration with Matplotlib, Seaborn, Plotly.
# - Easy integration with machine learning plugins (sckit-learn)
#
#
# -----------
# To read more about, Wes McKinney, the creator of Pandas, check out the article below.
#
# 1. https://qz.com/1126615/the-story-of-the-most-important-tool-in-data-science/
#
# --------------

# %% [markdown]
# ## Think of how we would try to represent a table in Python?

# %%
#A dicitonary of lists example
students = {
    'student_id': [1, 2, 3, 4, 5, 6],
    'name': ['Daenerys', 'Jon', 'Arya', 'Sansa', 'Eddard', 'Khal Drogo'],
    'course_mark': [82, 100, 12, 76, 46, 20],
    'species': ['cat', 'human', 'cat', 'human', 'human', 'human']
}

# %% [markdown]
# **What are some operations we might want to do on this data?**
#
# - 1.Select a subset of columns
# - 2.Filter out some rows based on an attribute
# - 3.Group by some attribute
# - 4.Compute some aggregate values within groups
# - 5.Save to a file
#
# How about we try out one of these to see how easy it is

# %% [markdown]
# ### Try to return a table with the mean course mark per-species.

# %%
# Return a table with the mean course mark per-species
# Think about a SQL statment where we group by species with the average course mark

species_sums = {} # Tables of Sums
species_counts = {} # Count per Species
for i in range(len(students['species'])):  # iterating over the rows
    species = students['species'][i] # every row number I get species 
    course_mark = students['course_mark'][i] # and course mark
    if species not in species_sums: # Intializing Species if not in list
        species_sums[species] = 0
        species_counts[species] = 0
    species_sums[species] += course_mark # Add each course mark for each species
    species_counts[species] += 1 

species_means = {}
                                  
for species in species_sums: # for every unique species we found
    species_means[species] = species_sums[species] / species_counts[species] # sum/count

species_means # return
# Out:
# {'cat': 47.0, 'human': 60.5}

# %% [markdown]
# - Did you like looking at is? Does this look fun to do?
# - Super Tiring.

# %% [markdown]
# ## Pandas Version

# %%
# Pandas Version
import pandas as pd

# Can take in a dictionry of list to instatiate a DataFrame
students = pd.DataFrame(students) 
students
# Out:
#    student_id        name  course_mark species
# 0           1    Daenerys           82     cat
# 1           2         Jon          100   human
# 2           3        Arya           12     cat
# 3           4       Sansa           76   human
# 4           5      Eddard           46   human
# 5           6  Khal Drogo           20   human

# %%
species_means = students[['species', 'course_mark']].groupby('species').mean()
# species_means = students.groupby('species')['course_mark'].mean()
species_means
# Out:
#          course_mark
# species
# cat             47.0
# human           60.5

# %% [markdown]
# ### Dissecting the above code!

# %%
#Step 1: Filter out the columns we want to keep
students_filtered = students[['species','course_mark']]
students_filtered
# Out:
#   species  course_mark
# 0     cat           82
# 1   human          100
# 2     cat           12
# 3   human           76
# 4   human           46
# 5   human           20

# %%
# Step 2: Group by species column
students_grouped_by_species = students_filtered.groupby('species') 
students_grouped_by_species

# %%
#Step 3: Specify how to aggregate the course-mark column
species_means = students_grouped_by_species.mean()

# %%
species_means
# Out:
#          course_mark
# species
# cat             47.0
# human           60.5

# %% [markdown]
# #### As shown, Pandas makes use of vectorized operations.

# %% [markdown]
# - Rather than use for-loops, we specify the operation that will apply to the structure as a whole (i.e. all the rows)
# - By vectorizing, **the code becomes more concise and more readable**
# - Pandas is optimized for vectorized operations (parallel vs. serial computation), which makes them **much faster**
# - It is almost always possible to vectorize operations on Pandas data types

# %% [markdown]
# ### Getting Started: Pandas Series & Pandas DataFrames
#
# There are two Pandas data types of interest:
#
# - Series (column)
#     - A pandas series is similar to an array but it has an index. The index is constant, and doesnt change through the operations we apply to the series.
# - DataFrame (table)
#     - A pandas dataframe is an object that is similar to a collection of pandas series.

# %%
# One way to construct a Series
series = pd.Series([82, 100, 12, 76, 46, 20]) 
series
# Out:
# 0     82
# 1    100
# 2     12
# 3     76
# 4     46
# 5     20
# dtype: int64

# %%
#We can specify some index when building a series. 
grades = pd.Series([82, 100, 12, 76, 46, 20], 
                   index = ['Daenerys', 'Jon', 'Arya', 'Sansa', 'Eddard', 'Khal Drogo'] ) 

grades
# Out:
# Daenerys       82
# Jon           100
# Arya           12
# Sansa          76
# Eddard         46
# Khal Drogo     20
# dtype: int64

# %%
print("The values:", grades.values)
print("The indexes:", grades.index)
# Out:
# The values: [ 82 100  12  76  46  20]
# The indexes: Index(['Daenerys', 'Jon', 'Arya', 'Sansa', 'Eddard', 'Khal Drogo'], dtype='object')

# %% [markdown]
# **Note:** The underlying index is still 0, 1, 2, 3.... and we can still index on that:

# %%
grades[2]
# Out:
# 12

# %% [markdown]
# ### Pandas DataFrames

# %%
# One way to construct a DataFrame
df = pd.DataFrame({
    'name': ['Daenerys', 'Jon', 'Arya', 'Sansa'],
    'course_mark': [82, 100, 12, 76],
    'species': ['human', 'human', 'cat', 'human']},
    index=[1412, 94, 9351, 14])
df
# Out:
#           name  course_mark species
# 1412  Daenerys           82   human
# 94         Jon          100   human
# 9351      Arya           12     cat
# 14       Sansa           76   human

# %% [markdown]
# #### Reading a CSV file
#
# We'll use the function `read_csv()` to load the data into our notebook
#
# - The `read_csv()` function can read data from a locally saved file or from a URL
# - We'll store the data as a variable `df_pokemon`

# %%
df_pokemon = pd.read_csv('data/pokemon.csv') # good practice to save dataframe info under 'df' then identifiers like 'pokemon'

# %%
df_pokemon # not the best practice if the dataframe is very large
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# **What do we see here?**
# - Each row of the table is an observation, containing data of a single pokemon

# %%
df_pokemon.shape # also tells us rows and columns
# Out:
# (800, 13)

# %% [markdown]
# For large DataFrames, it's often useful to display just the first few or last few rows:

# %%
df_pokemon.head(10) # gives the first 5 rows alike the LIMIT function of SQL
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# > **Pro tip:**
# > - To display the documentation for this method within Jupyter notebook, you can run the command `df_pokemon.head?` or press `Shift-Tab` within the parentheses of `df_pokemon.head()`
# > - To see other methods available for the DataFrame, type `df_pokemon.` followed by `Tab` for auto-complete options

# %%
df_pokemon.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# ## Data at a Glance
#
# `pandas` provides many ways to quickly and easily summarize your data:
# - How many rows and columns are there?
# - What are all the column names and what type of data is in each column?
# - How many values are missing in each column or row?
# - Numerical data: What is the average and range of the values?
# - Text data: What are the unique values and how often does each occur?

# %% [markdown]
# ### Peeking into the pokemon dataset
#
# - Similar with getting familar with SQL tables, it is often a great idea to look at the pandas dataframes we are working with. Below are some of the basic methods to glance at a dataset.

# %%
#Getting the Columns
df_pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#Getting Summary Statistics
df_pokemon.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %%
df_pokemon['Total'].describe() # the info from this column alone
# Out:
# count    800.00000
# mean     435.10250
# std      119.96304
# min      180.00000
# 25%      330.00000
# 50%      450.00000
# 75%      515.00000
# max      780.00000
# Name: Total, dtype: float64

# %%
df_pokemon[['Total','Attack']].describe() # now for two columns
# Out:
#            Total      Attack
# count  800.00000  800.000000
# mean   435.10250   79.001250
# std    119.96304   32.457366
# min    180.00000    5.000000
# 25%    330.00000   55.000000
# 50%    450.00000   75.000000
# 75%    515.00000  100.000000
# max    780.00000  190.000000

# %%
df_pokemon.Total.describe() # works only if the one column you want to look through has no spces
# Out:
# count    800.00000
# mean     435.10250
# std      119.96304
# min      180.00000
# 25%      330.00000
# 50%      450.00000
# 75%      515.00000
# max      780.00000
# Name: Total, dtype: float64

# %%
#Checking for Missing Data
df_pokemon.isnull().sum() # weithout the aggregate function it is difficult to parse through the missing files but with sum we can identify where it is missing
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# ## The .loc() vs .iloc() method
# ##### ---the method to find subsets of their data. Only difference is that iloc uses index integars
#
# To select rows and columns at the same time, we use the syntax `.loc[<rows>, <columns>]`:

# %%
#Notice the square brackets on loc and the colon
df_pokemon.loc[ : , ['Name']] # colon gets us all the rows for the column listed as Name
# you can add a .head() to the end to see the top 5 or you can change your colon to 0:4 which slices the top 5 only
# Out:
#                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]

# %%
#Taking a slice of index values
df_pokemon.loc[20:30,['Name']]
# Out:
#                    Name
# 20               Pidgey
# 21            Pidgeotto
# 22              Pidgeot
# 23  PidgeotMega Pidgeot
# 24              Rattata
# 25             Raticate
# 26              Spearow
# 27               Fearow
# 28                Ekans
# 29                Arbok
# 30              Pikachu

# %%
# Getting more than one columns
df_pokemon.loc[20:30,['Name','Legendary']]
# Out:
#                    Name  Legendary
# 20               Pidgey      False
# 21            Pidgeotto      False
# 22              Pidgeot      False
# 23  PidgeotMega Pidgeot      False
# 24              Rattata      False
# 25             Raticate      False
# 26              Spearow      False
# 27               Fearow      False
# 28                Ekans      False
# 29                Arbok      False
# 30              Pikachu      False

# %%
#we can also feed in a list for the rows
df_pokemon.loc[[1,8,21,7,432,666],['Name','Legendary']]
# Out:
#                           Name  Legendary
# 1                      Ivysaur      False
# 8    CharizardMega Charizard Y      False
# 21                   Pidgeotto      False
# 7    CharizardMega Charizard X      False
# 432                    Turtwig      False
# 666                     Elgyem      False

# %%
#We can also slice over  range of column values

# %%
#Iloc is use for integer based indexing
df_pokemon.iloc[0:3,1:4]
# Out:
#         Name Type 1  Type 2
# 0  Bulbasaur  Grass  Poison
# 1    Ivysaur  Grass  Poison
# 2   Venusaur  Grass  Poison

# %% [markdown]
# ### Modifying a Column or Creating a new column

# %%
# good practice to create a copy of the dataframe to keep track of the changes you make
df_pokemon_2 = df_pokemon.copy()

# %%
df_pokemon.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
# Combine 'Attack' + 'Special Attack'
df_pokemon['Total_Attack'] = df_pokemon['Attack'] + df_pokemon['Sp. Atk']
df_pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison   2544  45      49       49
# 1  2                Ivysaur  Grass  Poison   3240  60      62       63
# 2  3               Venusaur  Grass  Poison   4200  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison   5000  80     100      123
# 4  4             Charmander   Fire     NaN   2472  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_Attack  filler
# 0       65       65     45           1      False           114    True
# 1       80       80     60           1      False           142    True
# 2      100      100     80           1      False           182    True
# 3      122      120     80           1      False           222    True
# 4       60       50     65           1      False           112    True

# %%
#Create a filler column
df_pokemon['filler'] = True
df_pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison   2544  45      49       49
# 1  2                Ivysaur  Grass  Poison   3240  60      62       63
# 2  3               Venusaur  Grass  Poison   4200  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison   5000  80     100      123
# 4  4             Charmander   Fire     NaN   2472  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_Attack  filler
# 0       65       65     45           1      False           114    True
# 1       80       80     60           1      False           142    True
# 2      100      100     80           1      False           182    True
# 3      122      120     80           1      False           222    True
# 4       60       50     65           1      False           112    True

# %%
#Copy total and creat that

# %%
#Modify an orginal 
df_pokemon['Total'] = df_pokemon['Total'] * 2
df_pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison   2544  45      49       49
# 1  2                Ivysaur  Grass  Poison   3240  60      62       63
# 2  3               Venusaur  Grass  Poison   4200  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison   5000  80     100      123
# 4  4             Charmander   Fire     NaN   2472  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_Attack  filler
# 0       65       65     45           1      False           114    True
# 1       80       80     60           1      False           142    True
# 2      100      100     80           1      False           182    True
# 3      122      120     80           1      False           222    True
# 4       60       50     65           1      False           112    True

# %%
#Modify Data Frame with .loc() method
df_pokemon.loc[[1,2,3], ['Name']] = 'Andrew'
df_pokemon.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison   2544  45      49       49       65       65
# 1  2      Andrew  Grass  Poison   3240  60      62       63       80       80
# 2  3      Andrew  Grass  Poison   4200  80      82       83      100      100
# 3  3      Andrew  Grass  Poison   5000  80     100      123      122      120
# 4  4  Charmander   Fire     NaN   2472  39      52       43       60       50
#
#    Speed  Generation  Legendary  Total_Attack  filler
# 0     45           1      False           114    True
# 1     60           1      False           142    True
# 2     80           1      False           182    True
# 3     80           1      False           222    True
# 4     65           1      False           112    True

# %% [markdown]
# ### Sort_values() & value_counts()
#
# 1. ***df.sort_values()***
# 2. ***df.value_counts()***
#
#
# The ***pandas.sort_values()*** allows us to reorder our dataframe in an ascending or descending order given a column for pandas to work from. This is similar to the excel sort function.
#
# ```python
# import pandas as pd
# df = pd.read_csv('random.csv')
# df
#
#
# df.sort_values(by=['some_column'], ascending = True)
# ```
# In the above code snippet, we are sorting our *random.csv* pandas data frame by the column *some_column* in ascending order. To read more on the ***df.sort_values()*** function, read this [article](https://datatofish.com/sort-pandas-dataframe/).
#
# The second function is ***df.value_counts()***, it allows us to count how many times a specific value/item occurred in the dataframe. This function is best used on a specific column on a data frame, ideally on a column representing categorical data. Categorical data refers to a statistical data type consisting of categorical variables.
#
# ```python
# df['column'].value_counts()
# ```
#
# To read more on some of the advanced functionalities of ***df.value_counts()***, please refer to the pandas documentation or this [article](https://towardsdatascience.com/getting-more-value-from-the-pandas-value-counts-aa17230907a6).

# %%
df_pokemon.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison   2544  45      49       49       65       65
# 1  2      Andrew  Grass  Poison   3240  60      62       63       80       80
# 2  3      Andrew  Grass  Poison   4200  80      82       83      100      100
# 3  3      Andrew  Grass  Poison   5000  80     100      123      122      120
# 4  4  Charmander   Fire     NaN   2472  39      52       43       60       50
#
#    Speed  Generation  Legendary  Total_Attack  filler
# 0     45           1      False           114    True
# 1     60           1      False           142    True
# 2     80           1      False           182    True
# 3     80           1      False           222    True
# 4     65           1      False           112    True

# %%
df_pokemon.sort_values(by = ['Generation'], ascending=False) # we found ascending by shift+TAB to look at the variables
# Out:
#        #       Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 799  721  Volcanion      Fire    Water   4800   80     110      120      130
# 738  670    Floette     Fairy      NaN   2968   54      45       47       75
# 740  672     Skiddo     Grass      NaN   2800   66      65       48       62
# 741  673     Gogoat     Grass      NaN   4248  123     100       62       97
# 742  674    Pancham  Fighting      NaN   2784   67      82       62       46
# ..   ...        ...       ...      ...    ...  ...     ...      ...      ...
# 110  102  Exeggcute     Grass  Psychic   2600   60      40       80       60
# 109  101  Electrode  Electric      NaN   3840   60      50       70       80
# 108  100    Voltorb  Electric      NaN   2640   40      30       50       55
# 107   99    Kingler     Water      NaN   3800   55     130      115       50
# 0      1  Bulbasaur     Grass   Poison   2544   45      49       49       65
#
#      Sp. Def  Speed  Generation  Legendary  Total_Attack  filler
# 799       90     70           6       True           240    True
# 738       98     52           6      False           120    True
# 740       57     52           6      False           127    True
# 741       81     68           6      False           197    True
# 742       48     43           6      False           128    True
# ..       ...    ...         ...        ...           ...     ...
# 110       45     40           1      False           100    True
# 109       80    140           1      False           130    True
# 108       55    100           1      False            85    True
# 107       50     75           1      False           180    True
# 0         65     45           1      False           114    True
#
# [800 rows x 15 columns]

# %%
df_pokemon.sort_values(by = ['HP', 'Attack'], ascending = [True, False]) # where HP ascends and Attack descends
# Out:
#        #       Name    Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316  292   Shedinja       Bug  Ghost   1888    1      90       45       30
# 55    50    Diglett    Ground    NaN   2120   10      55       25       35
# 186  172      Pichu  Electric    NaN   1640   20      40       15       35
# 388  355    Duskull     Ghost    NaN   2360   20      40       90       30
# 487  439   Mime Jr.   Psychic  Fairy   2480   20      25       45       70
# ..   ...        ...       ...    ...    ...  ...     ...      ...      ...
# 655  594  Alomomola     Water    NaN   3760  165      75       80       40
# 351  321    Wailord     Water    NaN   4000  170      90       45       90
# 217  202  Wobbuffet   Psychic    NaN   3240  190      33       58       33
# 121  113    Chansey    Normal    NaN   3600  250       5        5       35
# 261  242    Blissey    Normal    NaN   4320  255      10       10       75
#
#      Sp. Def  Speed  Generation  Legendary  Total_Attack  filler
# 316       30     40           3      False           120    True
# 55        45     95           1      False            90    True
# 186       35     60           2      False            75    True
# 388       90     25           3      False            70    True
# 487       90     60           4      False            95    True
# ..       ...    ...         ...        ...           ...     ...
# 655       45     65           5      False           115    True
# 351       45     60           3      False           180    True
# 217       58     33           2      False            66    True
# 121      105     50           1      False            40    True
# 261      135     55           2      False            85    True
#
# [800 rows x 15 columns]

# %%
df_pokemon['Type 1'].value_counts() # see how often we get X data type
# can only search by one column at a time
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Dragon       32
# Ghost        32
# Ground       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
# order the above code further such as alphabetical or by count
df_pokemon['Type 1'].value_counts().sort_index()
# Out:
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Type 1, dtype: int64

# %%
#Just Unique Values (omit the count)
df_pokemon['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
#How many unique Values
df_pokemon['Type 1'].nunique()
# Out:
# 18

# %% [markdown]
# ### How to Query or Filter Data with Conditions?
#
# - We can extract specific data from our dataframe based on a specific condition. We will be using the syntax below. Pandas will return a subset of the dataframe based on the given condition.
#
# ```python
# df[<insert_condition>]
# ```
#
# Conditions follow the generic boolean logic in Python. Below is a cheat sheet python boolean logic.
#
# **Conditional Logic:**
#
# Conditional logic refers to the execution of different actions based on whether a certain condition is met. In programming, these conditions are expressed by a set of symbols called **Boolean Operators**.
#
# | Boolean Comparator | Example | Meaning                         |
# |--------------------|---------|---------------------------------|
# | >                  | x > y   | x is greater than y             |
# | >=                 | x >= y  | x is greater than or equal to y |
# | <                  | x < y   | x is less than y                |
# | <=                 | x <= y  | x is less than or equal to y    |
# | !=                 | x != y  | x is not equal to y             |
# | ==                 | x == y  | x is equal to y                 |

# %%
#Step 1: Create a filter
the_filter = df_pokemon['Total'] >= 500

# %%
#Step 2: Apply Filter
df_pokemon[the_filter]
# Out:
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison   2544  45      49       49
# 1      2               Andrew    Grass  Poison   3240  60      62       63
# 2      3               Andrew    Grass  Poison   4200  80      82       83
# 3      3               Andrew    Grass  Poison   5000  80     100      123
# 4      4           Charmander     Fire     NaN   2472  39      52       43
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy   4800  50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy   5600  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost   4800  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark   5440  80     160       60
# 799  721            Volcanion     Fire   Water   4800  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_Attack  filler
# 0         65       65     45           1      False           114    True
# 1         80       80     60           1      False           142    True
# 2        100      100     80           1      False           182    True
# 3        122      120     80           1      False           222    True
# 4         60       50     65           1      False           112    True
# ..       ...      ...    ...         ...        ...           ...     ...
# 795      100      150     50           6       True           200    True
# 796      160      110    110           6       True           320    True
# 797      150      130     70           6       True           260    True
# 798      170      130     80           6       True           330    True
# 799      130       90     70           6       True           240    True
#
# [800 rows x 15 columns]

# %%
#Finding Only Legendary Pokemons
the_filter = (df_pokemon['Total'] >= 500) & (df_pokemon['Legendary'] == True)

# %%
df_pokemon[the_filter]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying   4640   90      85
# 157  145               Zapdos  Electric    Flying   4640   90      90
# 158  146              Moltres      Fire    Flying   4640   90     100
# 162  150               Mewtwo   Psychic       NaN   5440  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting   6240  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy   4800   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy   5600   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost   4800   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark   5440   80     160
# 799  721            Volcanion      Fire     Water   4800   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_Attack  \
# 156      100       95      125     85           1       True           180
# 157       85      125       90    100           1       True           215
# 158       90      125       85     90           1       True           225
# 162       90      154       90    130           1       True           264
# 163      100      154      100    130           1       True           344
# ..       ...      ...      ...    ...         ...        ...           ...
# 795      150      100      150     50           6       True           200
# 796      110      160      110    110           6       True           320
# 797       60      150      130     70           6       True           260
# 798       60      170      130     80           6       True           330
# 799      120      130       90     70           6       True           240
#
#      filler
# 156    True
# 157    True
# 158    True
# 162    True
# 163    True
# ..      ...
# 795    True
# 796    True
# 797    True
# 798    True
# 799    True
#
# [65 rows x 15 columns]

# %% [markdown]
# Alternativly we can use the pandas **.where()** function, and it has the following syntax.
#
#
# ```python
# df.where(<condition>, <What to fill inplace where the condition is not True>) #default is Nan
# ```

# %%
df_pokemon.where(the_filter, 'Weak Pokemon') # good to filter out the condition true or not and this can be saved to another variable
# Out:
#                 #                 Name        Type 1        Type 2  \
# 0    Weak Pokemon         Weak Pokemon  Weak Pokemon  Weak Pokemon
# 1    Weak Pokemon         Weak Pokemon  Weak Pokemon  Weak Pokemon
# 2    Weak Pokemon         Weak Pokemon  Weak Pokemon  Weak Pokemon
# 3    Weak Pokemon         Weak Pokemon  Weak Pokemon  Weak Pokemon
# 4    Weak Pokemon         Weak Pokemon  Weak Pokemon  Weak Pokemon
# ..            ...                  ...           ...           ...
# 795           719              Diancie          Rock         Fairy
# 796           719  DiancieMega Diancie          Rock         Fairy
# 797           720  HoopaHoopa Confined       Psychic         Ghost
# 798           720   HoopaHoopa Unbound       Psychic          Dark
# 799           721            Volcanion          Fire         Water
#
#             Total            HP        Attack       Defense       Sp. Atk  \
# 0    Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon
# 1    Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon
# 2    Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon
# 3    Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon
# 4    Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon
# ..            ...           ...           ...           ...           ...
# 795          4800            50           100           150           100
# 796          5600            50           160           110           160
# 797          4800            80           110            60           150
# 798          5440            80           160            60           170
# 799          4800            80           110           120           130
#
#           Sp. Def         Speed    Generation     Legendary  Total_Attack  \
# 0    Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon
# 1    Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon
# 2    Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon
# 3    Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon
# 4    Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon  Weak Pokemon
# ..            ...           ...           ...           ...           ...
# 795           150            50             6          True           200
# 796           110           110             6          True           320
# 797           130            70             6          True           260
# 798           130            80             6          True           330
# 799            90            70             6          True           240
#
#            filler
# 0    Weak Pokemon
# 1    Weak Pokemon
# 2    Weak Pokemon
# 3    Weak Pokemon
# 4    Weak Pokemon
# ..            ...
# 795          True
# 796          True
# 797          True
# 798          True
# 799          True
#
# [800 rows x 15 columns]

# %% [markdown]
# ### Grouping and Aggregation
#
# Grouping and aggregation can be used to calculate statistics on groups in the data.
#
# **Common Aggregation Functions**
# - mean()
# - median()
# - sum()
# - count()

# %%
df_pokemon.groupby('Type 1').mean()
# Out:
#                    #        Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  3031.420290  56.884058   70.971014   70.724638
# Dark      461.354839  3565.935484  66.806452   88.387097   70.225806
# Dragon    474.375000  4404.250000  83.312500  112.125000   86.375000
# Electric  363.500000  3547.272727  59.795455   69.090909   66.295455
# Fairy     449.529412  3305.411765  74.117647   61.529412   65.705882
# Fighting  363.851852  3331.555556  69.851852   96.777778   65.925926
# Fire      327.403846  3664.615385  69.903846   84.769231   67.769231
# Flying    677.750000  3880.000000  70.750000   78.750000   66.250000
# Ghost     486.500000  3516.500000  64.437500   73.781250   81.187500
# Grass     344.871429  3369.142857  67.271429   73.214286   70.800000
# Ground    356.281250  3500.000000  73.781250   95.750000   84.843750
# Ice       423.541667  3467.666667  72.000000   72.750000   71.416667
# Normal    319.173469  3213.469388  77.275510   73.469388   59.846939
# Poison    251.785714  3193.142857  67.250000   74.678571   68.821429
# Psychic   380.807018  3807.578947  70.631579   71.456140   67.684211
# Rock      392.727273  3630.000000  65.363636   92.863636  100.795455
# Steel     442.851852  3901.629630  65.222222   92.703704  126.370370
# Water     303.089286  3443.642857  72.062500   74.151786   72.946429
#
#             Sp. Atk    Sp. Def       Speed  Generation  Legendary  \
# Type 1
# Bug       53.869565  64.797101   61.681159    3.217391   0.000000
# Dark      74.645161  69.516129   76.161290    4.032258   0.064516
# Dragon    96.843750  88.843750   83.031250    3.875000   0.375000
# Electric  90.022727  73.704545   84.500000    3.272727   0.090909
# Fairy     78.529412  84.705882   48.588235    4.117647   0.058824
# Fighting  53.111111  64.703704   66.074074    3.370370   0.000000
# Fire      88.980769  72.211538   74.442308    3.211538   0.096154
# Flying    94.250000  72.500000  102.500000    5.500000   0.500000
# Ghost     79.343750  76.468750   64.343750    4.187500   0.062500
# Grass     77.500000  70.428571   61.928571    3.357143   0.042857
# Ground    56.468750  62.750000   63.906250    3.156250   0.125000
# Ice       77.541667  76.291667   63.458333    3.541667   0.083333
# Normal    55.816327  63.724490   71.551020    3.051020   0.020408
# Poison    60.428571  64.392857   63.571429    2.535714   0.000000
# Psychic   98.403509  86.280702   81.491228    3.385965   0.245614
# Rock      63.340909  75.477273   55.909091    3.454545   0.090909
# Steel     67.518519  80.629630   55.259259    3.851852   0.148148
# Water     74.812500  70.517857   65.964286    2.857143   0.035714
#
#           Total_Attack  filler
# Type 1
# Bug         124.840580     1.0
# Dark        163.032258     1.0
# Dragon      208.968750     1.0
# Electric    159.113636     1.0
# Fairy       140.058824     1.0
# Fighting    149.888889     1.0
# Fire        173.750000     1.0
# Flying      173.000000     1.0
# Ghost       153.125000     1.0
# Grass       150.714286     1.0
# Ground      152.218750     1.0
# Ice         150.291667     1.0
# Normal      129.285714     1.0
# Poison      135.107143     1.0
# Psychic     169.859649     1.0
# Rock        156.204545     1.0
# Steel       160.222222     1.0
# Water       148.964286     1.0

# %% [markdown]
# - By default, `groupby()` assigns the variable that we're grouping on (in this case `Type 1`) to the index of the output data
# - If we use the keyword argument `as_index=False`, the grouping variable is instead assigned to a regular column
#   - This can be useful in some situations, such as data visualization functions which expect the relevant variables to be in columns rather than the index

# %%
df_pokemon.groupby('Type 1', as_index = False).sum() # lets us not use the grouping as a column, better for transforming later
# Out:
#       Type 1      #   Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0        Bug  23080  209168  3925    4897     4880     3717     4471   4256
# 1       Dark  14302  110544  2071    2740     2177     2314     2155   2361
# 2     Dragon  15180  140936  2666    3588     2764     3099     2843   2657
# 3   Electric  15994  156080  2631    3040     2917     3961     3243   3718
# 4      Fairy   7642   56192  1260    1046     1117     1335     1440    826
# 5   Fighting   9824   89952  1886    2613     1780     1434     1747   1784
# 6       Fire  17025  190560  3635    4408     3524     4627     3755   3871
# 7     Flying   2711   15520   283     315      265      377      290    410
# 8      Ghost  15568  112528  2062    2361     2598     2539     2447   2059
# 9      Grass  24141  235840  4709    5125     4956     5425     4930   4335
# 10    Ground  11401  112000  2361    3064     2715     1807     2008   2045
# 11       Ice  10165   83224  1728    1746     1714     1861     1831   1523
# 12    Normal  31279  314920  7573    7200     5865     5470     6245   7012
# 13    Poison   7050   89408  1883    2091     1927     1692     1803   1780
# 14   Psychic  21706  217032  4026    4073     3858     5609     4918   4645
# 15      Rock  17280  159720  2876    4086     4435     2787     3321   2460
# 16     Steel  11957  105344  1761    2503     3412     1823     2177   1492
# 17     Water  33946  385688  8071    8305     8170     8379     7898   7388
#
#     Generation  Legendary  Total_Attack  filler
# 0          222        0.0          8614    69.0
# 1          125        2.0          5054    31.0
# 2          124       12.0          6687    32.0
# 3          144        4.0          7001    44.0
# 4           70        1.0          2381    17.0
# 5           91        0.0          4047    27.0
# 6          167        5.0          9035    52.0
# 7           22        2.0           692     4.0
# 8          134        2.0          4900    32.0
# 9          235        3.0         10550    70.0
# 10         101        4.0          4871    32.0
# 11          85        2.0          3607    24.0
# 12         299        2.0         12670    98.0
# 13          71        0.0          3783    28.0
# 14         193       14.0          9682    57.0
# 15         152        4.0          6873    44.0
# 16         104        4.0          4326    27.0
# 17         320        4.0         16684   112.0

# %%
df_pokemon.groupby('Type 1', as_index = False)['Attack'].max() # not showing all the columns
# Out:
#       Type 1  Attack
# 0        Bug     185
# 1       Dark     150
# 2     Dragon     180
# 3   Electric     123
# 4      Fairy     131
# 5   Fighting     145
# 6       Fire     160
# 7     Flying     115
# 8      Ghost     165
# 9      Grass     132
# 10    Ground     180
# 11       Ice     130
# 12    Normal     160
# 13    Poison     106
# 14   Psychic     190
# 15      Rock     165
# 16     Steel     150
# 17     Water     155

# %%
df_pokemon.groupby(['Type 1', 'Legendary']).max() # index becomes a multi-index
# Out:
#                       #  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1   Legendary
# Bug      False      666   4800   86     185      230      135      230    160
# Dark     False      687   4800  110     150      125      140      130    125
#          True       717   5440  126     131       95      135       98    125
# Dragon   False      706   5600  108     170      130      120      150    120
#          True       718   6240  125     180      121      180      150    115
# Electric False      702   4880   90     123      115      165      110    140
#          True       642   4640   90     115       85      145      100    115
# Fairy    False      700   4416  101     120       95      120      154     80
#          True       716   5440  126     131       95      131       98     99
# Fighting False      701   5000  144     145       95      140      110    118
# Fire     False      668   5072  110     160      140      159      115    126
#          True       721   5440  115     130      120      130      154    100
# Flying   False      715   4280   85      70       80       97       80    123
#          True       641   4640   79     115       80      125       90    121
# Ghost    False      711   4800  150     165      145      170      135    130
#          True       487   5440  150     120      120      120      120     90
# Grass    False      673   5040  123     132      131      145      120    145
#          True       640   4800  100     103      100      120      129    127
# Ground   False      623   4280  115     140      130       81      120    120
#          True       645   6160  100     180      160      150       90    101
# Ice      False      713   4640  110     130      184      130      135    110
#          True       378   4640   90      85      100      100      200     85
# Normal   False      676   5360  255     160      126      135      135    135
#          True       493   5760  120     160      120      120      120    120
# Poison   False      691   4280  105     106      120      100      123    130
# Psychic  False      678   4944  190     165      120      175      135    150
#          True       720   6240  106     190      160      194      160    180
# Rock     False      703   5600  123     165      168      115      150    150
#          True       719   5600   91     160      200      160      150    110
# Steel    False      707   5600   80     150      230      150      150    110
#          True       638   5440  100     120      150      150      150    108
# Water    False      693   5120  170     155      180      135      140    122
#          True       484   6160  100     150      115      180      160    100
#
#                     Generation  Total_Attack  filler
# Type 1   Legendary
# Bug      False               6           240    True
# Dark     False               6           265    True
#          True                6           262    True
# Dragon   False               6           290    True
#          True                6           360    True
# Electric False               6           260    True
#          True                5           250    True
# Fairy    False               6           180    True
#          True                6           262    True
# Fighting False               6           285    True
# Fire     False               6           290    True
#          True                6           240    True
# Flying   False               6           167    True
#          True                5           240    True
# Ghost    False               6           258    True
#          True                4           240    True
# Grass    False               6           264    True
#          True                5           223    True
# Ground   False               5           195    True
#          True                5           330    True
# Ice      False               6           240    True
#          True                3           180    True
# Normal   False               6           255    True
#          True                4           240    True
# Poison   False               6           200    True
# Psychic  False               6           250    True
#          True                6           360    True
# Rock     False               6           259    True
#          True                6           320    True
# Steel    False               6           300    True
#          True                5           270    True
# Water    False               6           250    True
#          True                4           330    True

# %% [markdown]
# We can use the `agg` method to compute multiple aggregated statistics on our data, for example minimum and maximum country populations in each region:

# %%
df_pokemon.groupby('Type 1', as_index = False)['Attack'].agg(['min','max','mean'])
# Out:
#           min  max        mean
# Type 1
# Bug        10  185   70.971014
# Dark       50  150   88.387097
# Dragon     50  180  112.125000
# Electric   30  123   69.090909
# Fairy      20  131   61.529412
# Fighting   35  145   96.777778
# Fire       30  160   84.769231
# Flying     30  115   78.750000
# Ghost      30  165   73.781250
# Grass      27  132   73.214286
# Ground     40  180   95.750000
# Ice        30  130   72.750000
# Normal      5  160   73.469388
# Poison     43  106   74.678571
# Psychic    20  190   71.456140
# Rock       40  165   92.863636
# Steel      24  150   92.703704
# Water      10  155   74.151786

# %% [markdown]
# We can also use `agg` to compute different statistics for different columns:

# %%
agg_dict = {
    'Attack' : 'mean',
    'Defense' : ['min', 'max'] 
}

# %%
df_pokemon.groupby(['Type 1','Legendary'], as_index = False).agg(agg_dict)
# Out:
#       Type 1 Legendary      Attack Defense
#                               mean     min  max
# 0        Bug     False   70.971014      30  230
# 1       Dark     False   86.862069      30  125
# 2       Dark      True  110.500000      90   95
# 3     Dragon     False  103.400000      35  130
# 4     Dragon      True  126.666667      80  121
# 5   Electric     False   66.125000      15  115
# 6   Electric      True   98.750000      70   85
# 7      Fairy     False   57.187500      28   95
# 8      Fairy      True  131.000000      95   95
# 9   Fighting     False   96.777778      30   95
# 10      Fire     False   82.191489      37  140
# 11      Fire      True  109.000000      85  120
# 12    Flying     False   50.000000      35   80
# 13    Flying      True  107.500000      70   80
# 14     Ghost     False   71.366667      30  145
# 15     Ghost      True  110.000000     100  120
# 16     Grass     False   72.119403      30  131
# 17     Grass      True   97.666667      72  100
# 18    Ground     False   88.000000      25  130
# 19    Ground      True  150.000000      90  160
# 20       Ice     False   73.227273      15  184
# 21       Ice      True   67.500000     100  100
# 22    Normal     False   72.083333       5  126
# 23    Normal      True  140.000000     110  120
# 24    Poison     False   74.678571      35  120
# 25   Psychic     False   54.953488      15  120
# 26   Psychic      True  122.142857      20  160
# 27      Rock     False   89.925000      40  168
# 28      Rock      True  122.250000      90  200
# 29     Steel     False   92.086957      50  230
# 30     Steel      True   96.250000     100  150
# 31     Water     False   72.777778      20  180
# 32     Water      True  111.250000      90  115

# %% [markdown]
# ### Challenge 1 (20 minutes)
#
# Let's play around with Pandas on a more intricate dataset: a dataset on wines!
#
# **Challenge 14 from the 21 Day Data Challenge**
#
# Dot's neighbour said that he only likes wine from Stellenbosch, Bordeaux, and the Okanagan Valley, and that the sulfates can't be that high. The problem is, Dot can't really afford to spend tons of money on the wine. Dot's conditions for searching for wine are:
# 1. Sulfates cannot be higher than 0.6.
# 2. The price has to be less than  $20.
#
# Use the above conditions to filter the data for questions **2 and 3** below.
#
# **Questions:**
# 1. Where is Stellenbosch, anyway? How many wines from Stellenbosch are there in the *entire dataset*?
# 2. *After filtering with the 2 conditions*, what is the average price of wine from the Bordeaux region?
# 3. *After filtering with the 2 conditions*, what is the least expensive wine that's of the highest quality from the Okanagan Valley?
#
#
#
# **Stretch Question:**
# 1. What is the average price of wine from Stellenbosch, according to the entire unfiltered dataset?
#
#
# **Note: Check the dataset to see if there are missing values; if there are, fill in missing values with the mean.**

# %%
#Write your Code Below

# %%
import pandas as pd
df = pd.read_csv('winequality-red_2.csv')
df = df.drop(columns = ['Unnamed: 0'])

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality            region  price
# 0      9.4        5  Colchagua Valley     64
# 1      9.8        5          Bordeaux     89
# 2      9.8        5          La Rjoja     25
# 3      9.8        6        Willamette     27
# 4      9.4        5       Marlborough      9

# %%
df['region'].value_counts()
# Out:
# La Rjoja            341
# Bordeaux            264
# Colchagua Valley    260
# Okanagan Valley     256
# Willamette          233
# Marlborough         210
# Stellenbosch         35
# Name: region, dtype: int64

# %%
df_wine = (df['sulphates'] <= 0.6) & (df['price'] <= 20)

# %% [markdown]
# 2. *After filtering with the 2 conditions*, what is the average price of wine from the Bordeaux region?

# %%
df[df_wine].groupby(['region'])['price'].mean()
# Out:
# region
# Bordeaux            11.714286
# Colchagua Valley    13.818182
# La Rjoja            12.968750
# Marlborough         10.000000
# Okanagan Valley     11.000000
# Stellenbosch        17.333333
# Willamette          12.526316
# Name: price, dtype: float64

# %% [markdown]
# 3. After filtering with the 2 conditions, what is the least expensive wine that's of the highest quality from the Okanagan Valley?

# %%
df_wine = (df['sulphates'] <= 0.6) & (df['price'] <= 20) & (df['region'] == 'Okanagan Valley')

# %%
df[df_wine].sort_values(by=['quality', 'price'], ascending = [False,True]).head(1)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1025            8.6              0.83          0.0             2.8      0.095
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1025                 17.0                  43.0  0.99822  3.33        0.6
#
#       alcohol  quality           region  price
# 1025     10.4        6  Okanagan Valley      4

# %% [markdown]
# ### Challenge 2 (25 minutes)
#
# **Challenge 21 from the 21DDC (Adapted)**
#
# Dot wants to play retro video games with all their new friends! Help them figure out which games would be best.
#
# Questions:
#
# 1. What is the top 5 best selling games released before the year 2000.
#
#      -  **Note**: Use Global_Sales
#
#
# 2. Create a new column called Aggregate_Score, which returns the proportional average between Critic Score and User_Score based on Critic_Count and User_Count. Plot a horizontal bar chart of the top 5 highest rated games by Aggregate_Score, not published by Nintendo before the year 2000. From this bar chart, what is the highest rated game by Aggregate_Score?
#
#     -  **Note**: Critic_Count should be filled with the mean. User_Count should be filled with the median.
#
#
# #### In the exercise above, there is some missing values in the dataset. Look up the pandas documentation to figure out how to fill missing values in a column. You will be using the **ffill()** function.

# %%
df = pd.read_csv('video_games.csv')
df.head(2)
# Out:
#                 Name Platform  Year_of_Release     Genre Publisher  NA_Sales  \
# 0         Wii Sports      Wii           2006.0    Sports  Nintendo     41.36
# 1  Super Mario Bros.      NES           1985.0  Platform  Nintendo     29.08
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0     28.96      3.77         8.45         82.53          76.0          51.0
# 1      3.58      6.81         0.77         40.24           NaN           NaN
#
#    User_Score  User_Count Developer Rating
# 0         8.0       322.0  Nintendo      E
# 1         7.5         NaN       NaN    NaN

# %%
df_games = df.copy()
df_games.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         7.5         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         7.5         NaN       NaN    NaN

# %%
# Q1 What is the top 5 best selling games released before the year 2000.
filter_year = (df_games['Year_of_Release'] < 2000.0)
df_games[filter_year].sort_values(by='Global_Sales', ascending = False).head(5)
# Out:
#                            Name Platform  Year_of_Release         Genre  \
# 1             Super Mario Bros.      NES           1985.0      Platform
# 4      Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                        Tetris       GB           1989.0        Puzzle
# 9                     Duck Hunt      NES           1984.0       Shooter
# 12  Pokemon Gold/Pokemon Silver       GB           1999.0  Role-Playing
#
#    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 1   Nintendo     29.08      3.58      6.81         0.77         40.24
# 4   Nintendo     11.27      8.89     10.22         1.00         31.37
# 5   Nintendo     23.20      2.26      4.22         0.58         30.26
# 9   Nintendo     26.93      0.63      0.28         0.47         28.31
# 12  Nintendo      9.00      6.18      7.20         0.71         23.10
#
#     Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 1            NaN           NaN         7.5         NaN       NaN    NaN
# 4            NaN           NaN         7.5         NaN       NaN    NaN
# 5            NaN           NaN         7.5         NaN       NaN    NaN
# 9            NaN           NaN         7.5         NaN       NaN    NaN
# 12           NaN           NaN         7.5         NaN       NaN    NaN

# %% [markdown]
# Create a new column called Aggregate_Score, which returns the proportional average between Critic Score and User_Score based on Critic_Count and User_Count. Plot a horizontal bar chart of the top 5 highest rated games by Aggregate_Score, not published by Nintendo before the year 2000. From this bar chart, what is the highest rated game by Aggregate_Score?
#
# Note: Critic_Count should be filled with the mean. User_Count should be filled with the median.

# %% [markdown]
# 𝐴𝑔𝑔𝑟𝑒𝑔𝑎𝑡𝑒𝑆𝑐𝑜𝑟𝑒 = (𝐶𝑟𝑖𝑡𝑖𝑐𝐶𝑜𝑢𝑛𝑡 ∗ 𝐶𝑟𝑖𝑡𝑖𝑐𝑆𝑐𝑜𝑟𝑒) + (𝑈𝑠𝑒𝑟𝐶𝑜𝑢𝑛𝑡 ∗ 𝑈𝑠𝑒𝑟𝑆𝑐𝑜𝑟𝑒) / 𝑈𝑠𝑒𝑟𝐶𝑜𝑢𝑛𝑡 + 𝐶𝑟𝑖𝑡𝑖𝑐𝐶𝑜𝑢𝑛𝑡

# %%
df_games.Critic_Count.isnull().sum()
# Out:
# 0

# %%
df_games['Critic_Count'] = df_games['Critic_Count'].fillna(value = df_games.Critic_Score.mean())

# %%
df_games['User_Count'] = df_games['User_Count'].fillna(value = df_games.Critic_Score.median())

# %%
df_games['User_Score'] = df_games['User_Score'] * 10

# %%
df_games['Aggregate_Score'] = ((df_games.Critic_Count * df_games.Critic_Score) + (df_games.User_Count * df_games.User_Score)) / (df_games.User_Count + df_games.Critic_Count)

# %%
df_games["Aggregate_Score"].describe()
# Out:
# count    8137.000000
# mean       70.746777
# std        12.150460
# min        10.054054
# 25%        65.290541
# 50%        73.285714
# 75%        78.753247
# max        94.193168
# Name: Aggregate_Score, dtype: float64

# %%
nintendo_filter = df_games["Publisher"] != 'Nintendo'

# %%
nintendo = df_games[filter_year]
nintendo = nintendo[nintendo_filter]

nintendo.sort_values('Aggregate_Score', ascending = False).head(5)
# Out:
# /home/robyn/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                                     Name Platform  Year_of_Release  \
# 146                     Metal Gear Solid       PS           1998.0
# 1546  Castlevania: Symphony of the Night       PS           1997.0
# 1712                             Shenmue       DC           1999.0
# 5585        Harvest Moon: Back to Nature       PS           1999.0
# 65                     Final Fantasy VII       PS           1997.0
#
#              Genre                     Publisher  NA_Sales  EU_Sales  \
# 146         Action  Konami Digital Entertainment      3.18      1.83
# 1546      Platform  Konami Digital Entertainment      0.58      0.40
# 1712     Adventure                          Sega      0.52      0.24
# 5585    Simulation                       Ubisoft      0.11      0.07
# 65    Role-Playing   Sony Computer Entertainment      3.01      2.47
#
#       JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 146       0.78         0.24          6.03          94.0          20.0
# 1546      0.21         0.08          1.27          93.0          12.0
# 1712      0.38         0.04          1.18          88.0           9.0
# 5585      0.12         0.02          0.32          82.0           6.0
# 65        3.28         0.96          9.72          92.0          20.0
#
#       User_Score  User_Count                    Developer Rating  \
# 146         94.0       918.0                         KCEJ      M
# 1546        94.0       358.0                       Konami      T
# 1712        94.0       201.0                     Sega AM2      T
# 5585        93.0        78.0  Victor Interactive Software      E
# 65          92.0      1282.0                   SquareSoft      T
#
#       Aggregate_Score
# 146         94.000000
# 1546        93.967568
# 1712        93.742857
# 5585        92.214286
# 65          92.000000

# %% [markdown]
# # HINT
#
# **How to create the Aggregate Score Column?**
#
# \begin{equation*}
# AggregateScore = \frac{(CriticCount * CriticScore)+(UserCount * UserScore)}{UserCount + CriticCount}
# \end{equation*}
#
# **Check Your Column Values**
#
# The Critic_Score column is scored out of 100. The User_Score column is scored out of 10. You will need to modify one of the columns to match the other.

# %% [markdown]
# ## Documentation
#
# In the meantime, check out pandas the user guide in the [pandas documentation](https://pandas.pydata.org/docs/user_guide/index.html#user-guide).
#
# -------
# **Why should I use the documentation?**
#
# On the job as a data scientist or data analyst, more often than not, you may find yourself looking up the documentation of a particular function or plugin you use. Don't worry if there are a few functions you don't know by heart. However, there are just too many to know! An essential skill is to learn how to navigate documentation and understand how to apply the examples to your work.
#
# --------

# %% [markdown]
# Additional resources:
#
# - To learn more about these topics, as well as other topics not covered here (e.g. reshaping, merging, additional subsetting methods, working with text data, etc.) check out [these introductory tutorials](https://pandas.pydata.org/docs/getting_started/index.html#getting-started) from the `pandas` documentation
# - To learn more about subsetting your data, check out [this tutorial](https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html#min-tut-03-subset)
# - This [pandas cheatsheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf) may also be helpful as a reference.
